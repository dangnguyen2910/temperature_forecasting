# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\admin\\Downloads\\paris_temperature.csv")   #change the path
df.head(10)
# Out:
#            name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0  Paris,France  2023-10-01     26.5     12.5  18.9          26.5
# 1  Paris,France  2023-10-02     27.7     14.5  20.7          27.9
# 2  Paris,France  2023-10-03     22.1     15.0  18.8          22.1
# 3  Paris,France  2023-10-04     18.2     10.2  14.2          18.2
# 4  Paris,France  2023-10-05     19.8     11.0  14.7          19.8
# 5  Paris,France  2023-10-06     21.3      9.4  14.7          21.3
# 6  Paris,France  2023-10-07     23.9     10.5  16.7          23.9
# 7  Paris,France  2023-10-08     26.8     12.4  18.5          26.8
# 8  Paris,France  2023-10-09     26.0     13.7  18.9          26.0
# 9  Paris,France  2023-10-10     27.4     12.4  18.9          26.9
#
#    feelslikemin  feelslike   dew  humidity  ...  solarenergy  uvindex  \
# 0          12.5       18.9  13.7      74.3  ...          3.5        3
# 1          14.5       20.7  14.7      71.0  ...          4.4        4
# ...

# %%
df_1121 = df.iloc[:, 12:22]
df_1121.head(20)
# Out:
#     precipcover preciptype  snow  snowdepth  windgust  windspeed  winddir  \
# 0          4.17       rain   0.0        0.0      25.0       11.3    170.2
# 1          0.00        NaN   0.0        0.0      26.3       12.0    173.7
# 2         12.50       rain   0.0        0.0      51.6       22.8    277.2
# 3          4.17       rain   0.0        0.0      23.6       12.3    260.9
# 4          4.17       rain   0.0        0.0      16.3        6.8    238.3
# 5          4.17       rain   0.0        0.0      17.2        7.4    216.2
# 6          0.00        NaN   0.0        0.0      20.4        9.3    233.1
# 7          4.17       rain   0.0        0.0      18.1        9.3    176.1
# 8          0.00        NaN   0.0        0.0      14.4        7.1    266.1
# 9          0.00        NaN   0.0        0.0      25.4       13.3    219.4
# 10         4.17       rain   0.0        0.0      37.1       15.5    211.1
# 11        12.50       rain   0.0        0.0      29.2       13.5    219.8
# ...

# %%
df_1121["precipcover"].describe()
# Out:
# count    382.000000
# mean      15.674476
# std       16.936828
# min        0.000000
# 25%        0.000000
# 50%        8.330000
# 75%       25.000000
# max       75.000000
# Name: precipcover, dtype: float64

# %% [markdown]
# ## precipcover
#      Meaning: the proportion of a area that experienced precipitation
#
#      Value: % of the area experienced precipitation. Ranging from 0% to 75%
#
#      Feature type: Numerical

# %%
df_1121["preciptype"].value_counts(dropna=False)
# Out:
# preciptype
# rain                      301
# NaN                        74
# rain,snow                   6
# rain,freezingrain,snow      1
# Name: count, dtype: int64

# %% [markdown]
# ## preciptype
#     Meaning: the type of precipitation
#
#     Value: rain, no precipation, rain along with snow, rain with snow and freezing temperature. 4 catergory
#
#     Feature tpye: Categorical

# %%
df_1121["snow"].value_counts()
# Out:
# snow
# 0.0    375
# 0.6      2
# 0.1      2
# 0.3      1
# 0.2      1
# 5.4      1
# Name: count, dtype: int64

# %% [markdown]
# ## snow
#     Meaning: likely representing snowfall amount
#
#     Value: in mm  of liquid-equivalent snowfall
#
#     Feature type: Numerical

# %%
df_1121["snowdepth"].value_counts()
# Out:
# snowdepth
# 0.0    364
# 0.7      5
# 1.1      2
# 1.3      2
# 0.1      1
# 0.3      1
# 3.9      1
# 0.5      1
# 0.2      1
# 3.3      1
# 2.0      1
# 1.4      1
# 2.8      1
# Name: count, dtype: int64

# %% [markdown]
# ## snowdepth
#     Meaning: The depth of snow build up
#
#     Value: In centimeter
#
#     Feature type: Numerical

# %%
df_1121["windgust"].describe()
# Out:
# count    382.000000
# mean      41.781414
# std       13.497776
# min       14.400000
# 25%       32.200000
# 50%       39.100000
# 75%       50.000000
# max       92.200000
# Name: windgust, dtype: float64

# %% [markdown]
# ## windgust
#     Meaning: sharp bursts of wind that can be significantly higher than the average wind speed. Potentially the highest windspeed of the day
#
#     Value: kilometer per hours (km/h)
#
#     Feature type: Numerical

# %%
df_1121["windspeed"].describe()
# Out:
# count    382.000000
# mean      18.495550
# std        6.069653
# min        6.800000
# 25%       13.900000
# 50%       17.850000
# 75%       21.975000
# max       44.300000
# Name: windspeed, dtype: float64

# %% [markdown]
# ## windspeed
#     Meaning: a measure of how fast the wind is blowing
#
#     Value: kilometer per hours (km/h)
#
#     Feature type: Numerical

# %%
df_1121["winddir"].describe()
# Out:
# count    382.000000
# mean     209.079843
# std       87.970190
# min        0.400000
# 25%      180.750000
# 50%      222.000000
# 75%      265.675000
# max      358.200000
# Name: winddir, dtype: float64

# %% [markdown]
# ## winddir
#     Meaning: represent to wind direction
#
#     Value: In degree. 0° (or 360°) represents north, 90° represents east and so on
#
#     Feature type: Numerical

# %%
df_1121["sealevelpressure"].describe()
# Out:
# count     382.000000
# mean     1013.928796
# std        10.349025
# min       979.700000
# 25%      1008.900000
# 50%      1014.650000
# 75%      1019.900000
# max      1042.800000
# Name: sealevelpressure, dtype: float64

# %% [markdown]
# ## sealevelpressure
#     Meaning:  atmospheric pressure at sea level
#
#     Value: In milibars (mb) or hectopascals (hPa)
#
#     Feature type: Numerical

# %%
df_1121["cloudcover"].describe()
# Out:
# count    382.000000
# mean      79.876178
# std       19.049478
# min       13.000000
# 25%       71.200000
# 50%       85.600000
# 75%       94.075000
# max      100.000000
# Name: cloudcover, dtype: float64

# %% [markdown]
# ## cloudcover
#     Meaning: The coverage of cloud over an area
#
#     Value: In % over the area
#
#     Feature type: Numerical

# %%
df_1121["visibility"].describe()
# Out:
# count    382.000000
# mean      19.180628
# std        4.334291
# min        5.100000
# 25%       16.800000
# 50%       20.300000
# 75%       22.100000
# max       39.100000
# Name: visibility, dtype: float64

# %% [markdown]
# ## visibility
#     Meaning: indicates how far one can see
#
#     Value: Kilometer (km)
#
#     Feature type: Numerical
